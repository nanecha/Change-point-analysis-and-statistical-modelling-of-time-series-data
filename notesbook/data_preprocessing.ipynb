# %% [markdown]
# # Task 1: Laying the Foundation for Analysis

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
from src import data_eda

# %%
from src.data_eda import load_data, preview_data, show_info, show_shape, summarize_data, check_missing_values, check_duplicates, plot_brent_prices
# Load data

# %% [markdown]
# ## Data loading Brent oil data

# %%
df = load_data('F:/Change-point-analysis-and-statistical-modelling-of-time-series-data/data/BrentOilPrices.csv')
df.head(10)
# Out:
#         Date  Price
# 0  20-May-87  18.63
# 1  21-May-87  18.45
# 2  22-May-87  18.55
# 3  25-May-87  18.60
# 4  26-May-87  18.63
# 5  27-May-87  18.60
# 6  28-May-87  18.60
# 7  29-May-87  18.58
# 8  01-Jun-87  18.65
# 9  02-Jun-87  18.68

# %% [markdown]
# ## Understanding about each column

# %%
# Preview and understand
preview_data(df)
show_info(df)
show_shape(df)
print(summarize_data(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9011 entries, 0 to 9010
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    9011 non-null   object
#  1   Price   9011 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 140.9+ KB
# Shape of dataset: (9011, 2)
#              Price
# count  9011.000000
# mean     48.420782
# std      32.860110
# min       9.100000
# 25%      19.050000
# 50%      38.570000
# 75%      70.090000
# max     143.950000

# %% [markdown]
# # statistical summary of the data

# %%
# statistical summary of the data
df.describe()
# Out:
#              Price
# count  9011.000000
# mean     48.420782
# std      32.860110
# min       9.100000
# 25%      19.050000
# 50%      38.570000
# 75%      70.090000
# max     143.950000

# %% [markdown]
# # checking for missing values

# %%
# checking for missing values
# Data quality checks
print("Missing values:\n", check_missing_values(df))
print("Duplicate rows:", check_duplicates(df))
# Out:
# Missing values:
#  Date     0
# Price    0
# dtype: int64
# Duplicate rows: 0

# %%
# visualizing the data
# Visualize
plot_brent_prices(df)

# %%
# make for individual cell function
